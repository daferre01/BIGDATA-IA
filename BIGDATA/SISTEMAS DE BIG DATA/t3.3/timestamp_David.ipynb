# %% [markdown]
# # T3.4: Análise con Pandas e travel-times

# %% [markdown]
# ### Series temporais
#
# travel_times_df = pd.read_csv("X:/jfsanchez/datasets/travel-times.csv")
# travel_times_df.info()
#
# Fai:
#
#     Calcular o endtime (StartTime+TotalTime).
#     Eliminar as columnas na que máis da metade dos valores sexan nulos.
#     Visualizar o número de nulos de cada columna.
#     Substitúe os valores nules empregando o valor da fila anterior (method='ffil').
#     Os primeiros valores son NaN, debemos corrixilo substituíndo estes valores polos anteriores (method='bfill').
#
# Máis información:
#
#     https://wesmckinney.com/book/time-series#tseries_resampling

# %%
import pandas as pd

# %%
df=pd.read_csv('travel-times.csv')

# %%
df
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011     08:09     Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011     08:03   Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08  Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    Home     51.73     125.0      62.8
#
#      AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# ...

# %%
import datetime


df['EndTime'] = df['StartTime'] - datetime.timedelta(min=df['TotalTime'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 import datetime
# ----> 4 df['EndTime'] = df['StartTime'] - datetime.timedelta(min=df['TotalTime'])
#
# TypeError: 'min' is an invalid keyword argument for __new__()
